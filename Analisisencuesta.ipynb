# %% [markdown]
# <a href="https://colab.research.google.com/github/jlazo3010/An-lisis_datos/blob/main/Analisisencuesta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 4
# 4#AQUÍ VA EL ANALISIS

# %%
import pandas as pd
import matplotlib.pyplot as plt
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vScAvGq-vtEUwWcklqpof8HLxpEVzIl1zayws2aBtWx1pkTQXcRIVCVNeGdfhl4DczK74UCBik5NSvv/pub?gid=124623622&single=true&output=csv'
df = pd.read_csv(url)

# %%
from google.colab import drive
drive.mount('/content/drive') #Nos conectamos a nuestro drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Crearemos aqui las tablas de datos cruzados para un analisis de relación de la columna de sentimiento que predomino con todas las demas

# %%
tabla1=pd.crosstab(index=df['¿Cuánto tiempo has estado en confinamiento?'],
            columns=df['¿Qué sentimiento ha predominado en ti durante el confinamiento?'], margins=True)#Tabla de relación entre tiempo de confinamiento y sentimiento

# %%
tabla2=pd.crosstab(index=df['¿En que rango de edad te encuentras?'],
            columns=df['¿Qué sentimiento ha predominado en ti durante el confinamiento?'], margins=True)#Tabla de relación entre rango de edad y sentimiento

# %%
tabla3=pd.crosstab(index=df['¿Con cuántas personas vives?'],
            columns=df['¿Qué sentimiento ha predominado en ti durante el confinamiento?'], margins=True)#Tabla de relación entre personas por vivienda y sentimiento

# %%
tabla4=pd.crosstab(index=df['¿Tienes mascotas?'],
            columns=df['¿Qué sentimiento ha predominado en ti durante el confinamiento?'], margins=True)#Tabla de relación entre tener alguna mascota y sentimiento

# %%
tabla5=pd.crosstab(index=df['¿Cómo calificarías tu economía durante este periodo?'],
            columns=df['¿Qué sentimiento ha predominado en ti durante el confinamiento?'], margins=True)#Tabla de relación entre economia y sentimiento

# %%
tabla6=pd.crosstab(index=df['¿Cuál de las siguientes actividades comenzaste a realizar durante la cuarentena?'],
            columns=df['¿Qué sentimiento ha predominado en ti durante el confinamiento?'], margins=True)#Tabla de relación entre actividad durante el confinamiento y sentimiento

# %%
tabla7=pd.crosstab(index=df['¿Has tenido problemas para dormir?'],
            columns=df['¿Qué sentimiento ha predominado en ti durante el confinamiento?'], margins=True)#Tabla de relación entre insomnio y sentimiento

# %%
tabla8=pd.crosstab(index=df['¿Cómo crees que has afrontado emocionalmente el confinamiento?'],
            columns=df['¿Qué sentimiento ha predominado en ti durante el confinamiento?'], margins=True)#Tabla de relación entre la idea de como se afronta el confinamiento y sentimiento

# %% [markdown]
# ##En esta parte estaría chido poner las tablas de frecuencia por cada columna para ver la distribución de los datos

# %%
edades = df['¿En que rango de edad te encuentras?'].value_counts()
tiempo = df['¿Cuánto tiempo has estado en confinamiento?'].value_counts()
mascotas = df['¿Tienes mascotas?'].value_counts()
insomnio = df['¿Has tenido problemas para dormir?'].value_counts()
afrontamiento = df['¿Cómo crees que has afrontado emocionalmente el confinamiento?'].value_counts()
actividades = df['¿Cuál de las siguientes actividades comenzaste a realizar durante la cuarentena?'].value_counts()
economia = df['¿Cómo calificarías tu economía durante este periodo?'].value_counts()
personas = df['¿Con cuántas personas vives?'].value_counts()
sentimiento = df['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()

# %% [markdown]
# ## Sentimientos segmentados por edades con tabla de frecuencias

# %%
adolescentes = df[df["¿En que rango de edad te encuentras?"]=="De 21 a 30 años"]
adultos = df[df["¿En que rango de edad te encuentras?"]=="De 31 a 40 años"]
masadultos = df[df["¿En que rango de edad te encuentras?"]=="De 41 a 50 años"]
terceraedad = df[df["¿En que rango de edad te encuentras?"]=="Más de 51 años"]
adolescentes1 = adolescentes['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()
adultos1 = adultos['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()
masadultos1 = masadultos['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()
terceraedad1 = terceraedad['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()

# %% [markdown]
# ## Aqui podemos poner todos los graficos de datos cruzados o las distribuciones de lo anterior que se nos ocurra.

# %%
colores = ["#EE6055","#60D394","#AAF683","#FFD97D","#FF9B85", "lightblue"]
desfase = (0.05, 0, 0, 0,0)
plot = edades.plot.pie(y=edades,figsize = (10,7),autopct="%0.1f %%", colors=colores,explode=desfase) #Ejemplo de grafico de pastel
plt.savefig('/content/drive/Shareddrives/Vídeos Caro y Jorge/edadesrespuestas.png',bbox_inches='tight') #Ejemplo de guardar una grafica en nuestra carpeta compartida de drive

# %%
figure, axes = plt.subplots()
plt.subplot(221)
p1 = adolescentes1.plot.bar(y=adolescentes1,figsize = (15,12), color=colores)
plt.title('De 21 a 30 años')

plt.subplot(222)
p2 = masadultos1.plot.bar(y=masadultos1,figsize = (15,12), color=colores)
plt.title('De 41 a 50 años')

plt.subplot(223)
p3 = adultos1.plot.bar(y=adultos1,figsize = (15,12), color=colores)
plt.title('De 31 a 40 años')

plt.subplot(224)
p4 = terceraedad1.plot.bar(y=terceraedad1,figsize = (15,12), color=colores)
plt.title('Más de 51 años')
figure.tight_layout()
plt.savefig('/content/drive/Shareddrives/Vídeos Caro y Jorge/edades_sentimiento.png',bbox_inches='tight')

# %%
pd.crosstab(index=df['¿Cuánto tiempo has estado en confinamiento?'],
            columns=df['¿Cómo calificarías tu economía durante este periodo?']).apply(lambda r: r/r.sum() *100,
                                              axis=1).plot(kind='bar', figsize = (10,10), title="Economia vs tiempo de confinamiento")
                                            #Ejemplo de grafico cruzando datos
plt.savefig('/content/drive/Shareddrives/Vídeos Caro y Jorge/graficachida2.png',bbox_inches='tight')

# %%
acompañado = df[df['¿Con cuántas personas vives?']=="De 1 a 2"]
muyacompañado = df[df['¿Con cuántas personas vives?']=="De 2 a 5"]
masqueacompañado = df[df['¿Con cuántas personas vives?']=="Más de 5"]
solo = df[df['¿Con cuántas personas vives?']=="Ninguna, solo yo"]
acompañado1 = acompañado['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()
muyacompañado1 = muyacompañado['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()
masqueacompañado1 = masqueacompañado['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()
solo1 = solo['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()

# %%
figure, axes = plt.subplots()
plt.subplot(221)
p1 = acompañado1.plot.bar(y=acompañado1,figsize = (15,12), color=colores)
plt.title('De 1 a 2 personas')

plt.subplot(222)
p2 = muyacompañado1.plot.bar(y=muyacompañado1,figsize = (15,12), color=colores)
plt.title('De 2 a 5 personas')

plt.subplot(223)
p3 = masqueacompañado1.plot.bar(y=masqueacompañado1,figsize = (15,12), color=colores)
plt.title('Más de 5 personas')

plt.subplot(224)
p4 = solo1.plot.bar(y=solo1,figsize = (15,12), color=colores)
plt.title('Solo')
figure.tight_layout()
plt.savefig('/content/drive/Shareddrives/Vídeos Caro y Jorge/personas_sentimiento.png',bbox_inches='tight')

# %%
bien = df[df['¿Cómo crees que has afrontado emocionalmente el confinamiento?']=="Bien"]
Mal = df[df['¿Cómo crees que has afrontado emocionalmente el confinamiento?']=="Mal"]
Muybien = df[df['¿Cómo crees que has afrontado emocionalmente el confinamiento?']=="Muy bien"]
Maso = df[df['¿Cómo crees que has afrontado emocionalmente el confinamiento?']=="Maso"]
peor = df[df['¿Cómo crees que has afrontado emocionalmente el confinamiento?']=="Podria ser peor"]
bien1 = bien['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()
Mal1 = Mal['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()
Muybien1 = Muybien['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()
Maso1 = Maso['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()
peor1 = peor['¿Qué sentimiento ha predominado en ti durante el confinamiento?'].value_counts()

# %%
figure, axes = plt.subplots()
plt.subplot(231)
p1 = bien1.plot.bar(y=bien1,figsize = (15,12), color=colores)
plt.title('Bien')

plt.subplot(232)
p2 = Mal1.plot.bar(y=Mal1,figsize = (15,12), color=colores)
plt.title('Mal')

plt.subplot(233)
p3 = Muybien1.plot.bar(y=Muybien1,figsize = (15,12), color=colores)
plt.title('Muy bien')

plt.subplot(234)
p4 = Maso1.plot.bar(y=Maso1,figsize = (15,12), color=colores)
plt.title('Maso')

plt.subplot(235)
p4 = peor1.plot.bar(y=peor1,figsize = (15,12), color=colores)
plt.title('Podría ser peor')
figure.tight_layout()
plt.savefig('/content/drive/Shareddrives/Vídeos Caro y Jorge/afrontamiento_sentimiento.png',bbox_inches='tight')

# %%
bien2 = bien['¿Has tenido problemas para dormir?'].value_counts()
Mal2 = Mal['¿Has tenido problemas para dormir?'].value_counts()
Muybien2 = Muybien['¿Has tenido problemas para dormir?'].value_counts()
Maso2 = Maso['¿Has tenido problemas para dormir?'].value_counts()
peor2 = peor['¿Has tenido problemas para dormir?'].value_counts()

# %%
figure, axes = plt.subplots()

plt.subplot(231)
p1 = bien2.plot.bar(y=bien2,figsize = (15,12), color=colores)
plt.title('Bien')

plt.subplot(232)
p2 = Mal2.plot.bar(y=Mal2,figsize = (15,12), color=colores)
plt.title('Mal')

plt.subplot(233)
p3 = Muybien2.plot.bar(y=Muybien2,figsize = (15,12), color=colores)
plt.title('Muy bien')

plt.subplot(234)
p4 = Maso2.plot.bar(y=Maso2,figsize = (15,12), color=colores)
plt.title('Maso')

plt.subplot(235)
p4 = peor2.plot.bar(y=peor2,figsize = (15,12), color=colores)
plt.title('Podría ser peor')
figure.tight_layout()
plt.savefig('/content/drive/Shareddrives/Vídeos Caro y Jorge/insomnio_afrontamiento.png',bbox_inches='tight')

# %%
comentarios = df['Describe brevemente tu experiencia durante la cuarentena']
todo = []
for i in range(len(comentarios)):
  todo.append(comentarios.iloc[i])
todito = ''.join(todo)
todito = todito.lower()

# %%
from wordcloud import WordCloud
nube = WordCloud().generate(todito)
plt.imshow(nube,interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
import stylecloud
from stop_words import get_stop_words

palabras_irrelevantes = get_stop_words('spanish')

stylecloud.gen_stylecloud(text= todito,
                          icon_name="fas fa-head-side-mask",
                          palette='cartocolors.qualitative.Pastel_3',
                          background_color='black',
                          output_name='nubepalabras.png',
                          collocations=False,
                          custom_stopwords=palabras_irrelevantes)
